# %% [markdown]
# ## **Importing Modules**

# %%
#importing required modules

import gdown
import zipfile
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

import torchvision.models as models
import torch
import torch.nn as nn
from torchsummary import summary
from torchvision import datasets, transforms as T
from torch.utils.data import Dataset, DataLoader

import os
import torch.optim as optim
from PIL import ImageFile

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, accuracy_score, roc_curve

# %% [markdown]
# ## **Data Preprocessing**

# %%
#importing data

#Dataset address
url = 'https://drive.google.com/uc?export=download&id=1B75cOYH7VCaiqdeQYvMuUuy_Mn_5tPMY'
output = 'data.zip'
gdown.download(url, output, quiet=False)

#giving zip file name
data_dir='./data.zip'

#extractng data from zip file
with zipfile.ZipFile(data_dir, 'r') as zf:
    zf.extractall('./data')
    print('Done downloading and extraction')

#removing zip file after extraction
# !rm './data.zip' 

#invstigating number of files
orange_files = np.array(glob("/content/data/*/*/*"))
print('There are %d total chest xray images.' % len(orange_files))

#checking the availability of a GPU
use_cuda = torch.cuda.is_available()
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1B75cOYH7VCaiqdeQYvMuUuy_Mn_5tPMY
# To: /content/data.zip
# 100%|██████████| 46.1M/46.1M [00:00<00:00, 169MB/s]
# Done downloading and extraction
# There are 4626 total chest xray images.

# %%
transform = T.Compose([T.ToTensor(),])
orange_file='./data/'

train_path=os.path.join(orange_file,'train')
dataset = datasets.ImageFolder(train_path,transform=transform)
dataloader = DataLoader(dataset, batch_size=1, num_workers=1, shuffle=False)

mean = torch.zeros(3)
std = torch.zeros(3)

for i, data in enumerate(dataloader):
    if (i % 10000 == 0): print(i)
    data = data[0].squeeze(0)
    if (i == 0): size = data.size(1) * data.size(2)
    mean += data.sum((1, 2)) / size

mean /= len(dataloader)
print(mean)
mean = mean.unsqueeze(1).unsqueeze(2)

for i, data in enumerate(dataloader):
    if (i % 10000 == 0): print(i)
    data = data[0].squeeze(0)
    std += ((data - mean) ** 2).sum((1, 2)) / size

std /= len(dataloader)
std = std.sqrt()
print(std)
# Out:
# 0
# tensor([0.5219, 0.5220, 0.5223])
# 0
# tensor([0.2476, 0.2476, 0.2477])

# %%
#declaring batch size
batch_size = 16

#applying required transformations on the dataset
img_transforms = {
    'train':
    T.Compose([
       
        T.RandomCrop(size=(224,224)), 
        T.ToTensor(),
        T.Normalize((0.5219, 0.5220, 0.5223), (0.2476, 0.2476, 0.2477)),
    ]),
    

    'valid':
    T.Compose([
          
        T.RandomCrop(size=(224,224)),
        T.ToTensor(),
        T.Normalize((0.5219, 0.5220, 0.5223), (0.2476, 0.2476, 0.2477)),
    ]),


    'test':
    T.Compose([
              
        T.RandomCrop(size=(224,224)),
        T.ToTensor(),
        T.Normalize((0.5219, 0.5220, 0.5223), (0.2476, 0.2476, 0.2477)),
    ]),
}


#  creating Location of data: train, validation, test
orange_file='./data/'

train_path=os.path.join(orange_file,'train')
valid_path=os.path.join(orange_file,'valid')
test_path=os.path.join(orange_file,'test')


# creating Datasets to each of  folder created in prev
train_file=datasets.ImageFolder(train_path,transform=img_transforms['train'])
valid_file=datasets.ImageFolder(valid_path,transform=img_transforms['valid'])
test_file=datasets.ImageFolder(test_path,transform=img_transforms['test'])


#Creating loaders for the dataset
loaders_transfer={
    'train':torch.utils.data.DataLoader(train_file,batch_size,shuffle=True),
    'valid':torch.utils.data.DataLoader(valid_file,batch_size,shuffle=True),
    'test': torch.utils.data.DataLoader(test_file,batch_size,shuffle=False)
}

# %% [markdown]
# ## **Model Building**

# %%
#importing the pretrained VGG16 model
model_transfer = models.vgg19(pretrained=True)

# Freeze weights
for param in model_transfer.features.parameters():
    param.requires_grad = False


# Defining Dense top layers after the convolutional layers
model_transfer.classifier = nn.Sequential(
    
    nn.Linear(25088, 1024),
    nn.LeakyReLU(inplace = True),
          
    nn.Linear(1024,256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(256,128),
    nn.LeakyReLU(inplace=True),
    nn.Linear(128,32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(32,2),
    nn.Sigmoid()
)

# transfering the model on the GPU
if use_cuda:
    model_transfer = model_transfer.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
# Plotting the summary of the model
summary(model_transfer, (3, 224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 1024]      25,691,136
#         LeakyReLU-40                 [-1, 1024]               0
#            Linear-41                  [-1, 256]         262,400
#         LeakyReLU-42                  [-1, 256]               0
#            Linear-43                  [-1, 128]          32,896
#         LeakyReLU-44                  [-1, 128]               0
#            Linear-45                   [-1, 32]           4,128
#         LeakyReLU-46                   [-1, 32]               0
#            Linear-47                    [-1, 2]              66
#           Sigmoid-48                    [-1, 2]               0
# ================================================================
# Total params: 46,015,010
# Trainable params: 25,990,626
# Non-trainable params: 20,024,384
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.51
# Params size (MB): 175.53
# Estimated Total Size (MB): 414.62
# ----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# selecting loss function
criterion_transfer = nn.CrossEntropyLoss()

#using Adam Optimizer
optimizer_transfer = optim.Adam(model_transfer.classifier.parameters(), lr=0.0005,weight_decay=1e-4)

# %% [markdown]
# ## **Training and Validating the Model**

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Creating the function for training
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    trainingloss = []
    validationloss = []

    for epoch in range(1, n_epochs+1):
        # initialize the variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        correct1 = 0.
        total1 = 0.
        correct2 = 0.
        total2 = 0.

        ###################
        # training the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
          
            optimizer.zero_grad()
            output = model(data)

            loss = criterion(output, target)
            
            loss.backward()
            optimizer.step()
           
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions
            correct1 += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total1 += data.size(0)

       
        ######################    
        # validating the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            
            output = model(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions
            correct2 += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total2 += data.size(0)

      

        train_loss = train_loss/len(train_file)
        valid_loss = valid_loss/len(valid_file)

        trainingloss.append(train_loss)
        validationloss.append(valid_loss)
        acc1 = 100. * correct1 / total1
        acc2 =  100. * correct2 / total2
        # printing training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining Accuracy: {:.4f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.4f}'.format(
            epoch,
            train_loss,
            acc1,
            valid_loss,
            acc2
            ))
        
        ## saving the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            
            valid_loss_min = valid_loss
            
    # return trained model
    return model, trainingloss, validationloss

# %%
# training the model

n_epochs=50

model_transfer, train_loss, valid_loss = train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')
# Out:
# Epoch: 1 	Training Loss: 0.000116 	Training Accuracy: 88.0605 	Validation Loss: 0.001061 	Validation Accuracy: 82.0346
# Validation loss decreased (inf --> 0.001061).  Saving model ...
# Epoch: 2 	Training Loss: 0.000106 	Training Accuracy: 91.7882 	Validation Loss: 0.000935 	Validation Accuracy: 87.8788
# Validation loss decreased (0.001061 --> 0.000935).  Saving model ...
# Epoch: 3 	Training Loss: 0.000104 	Training Accuracy: 92.5716 	Validation Loss: 0.000815 	Validation Accuracy: 93.5065
# Validation loss decreased (0.000935 --> 0.000815).  Saving model ...
# Epoch: 4 	Training Loss: 0.000104 	Training Accuracy: 92.7066 	Validation Loss: 0.000835 	Validation Accuracy: 92.4242
# Epoch: 5 	Training Loss: 0.000098 	Training Accuracy: 94.6515 	Validation Loss: 0.000807 	Validation Accuracy: 93.9394
# Validation loss decreased (0.000815 --> 0.000807).  Saving model ...
# Epoch: 6 	Training Loss: 0.000098 	Training Accuracy: 94.8406 	Validation Loss: 0.000950 	Validation Accuracy: 87.4459
# Epoch: 7 	Training Loss: 0.000100 	Training Accuracy: 93.9492 	Validation Loss: 0.000847 	Validation Accuracy: 91.7749
# Epoch: 8 	Training Loss: 0.000099 	Training Accuracy: 94.6245 	Validation Loss: 0.000802 	Validation Accuracy: 94.1558
# Validation loss decreased (0.000807 --> 0.000802).  Saving model ...
# Epoch: 9 	Training Loss: 0.000099 	Training Accuracy: 94.5975 	Validation Loss: 0.000816 	Validation Accuracy: 93.5065
# Epoch: 10 	Training Loss: 0.000097 	Training Accuracy: 95.1108 	Validation Loss: 0.000807 	Validation Accuracy: 93.7229
# Epoch: 11 	Training Loss: 0.000099 	Training Accuracy: 94.2734 	Validation Loss: 0.000845 	Validation Accuracy: 92.8571
# Epoch: 12 	Training Loss: 0.000099 	Training Accuracy: 94.3544 	Validation Loss: 0.000802 	Validation Accuracy: 93.9394
# Validation loss decreased (0.000802 --> 0.000802).  Saving model ...
# Epoch: 13 	Training Loss: 0.000099 	Training Accuracy: 94.7326 	Validation Loss: 0.000813 	Validation Accuracy: 93.5065
# Epoch: 14 	Training Loss: 0.000101 	Training Accuracy: 93.7331 	Validation Loss: 0.000823 	Validation Accuracy: 93.2900
# Epoch: 15 	Training Loss: 0.000097 	Training Accuracy: 95.1648 	Validation Loss: 0.000825 	Validation Accuracy: 92.2078
# Epoch: 16 	Training Loss: 0.000099 	Training Accuracy: 94.5975 	Validation Loss: 0.000820 	Validation Accuracy: 92.8571
# Epoch: 17 	Training Loss: 0.000097 	Training Accuracy: 95.2998 	Validation Loss: 0.000810 	Validation Accuracy: 93.9394
# Epoch: 18 	Training Loss: 0.000099 	Training Accuracy: 94.5975 	Validation Loss: 0.000823 	Validation Accuracy: 92.6407
# Epoch: 19 	Training Loss: 0.000098 	Training Accuracy: 94.8947 	Validation Loss: 0.000782 	Validation Accuracy: 95.0216
# Validation loss decreased (0.000802 --> 0.000782).  Saving model ...
# Epoch: 20 	Training Loss: 0.000096 	Training Accuracy: 95.4889 	Validation Loss: 0.000824 	Validation Accuracy: 93.0736
# Epoch: 21 	Training Loss: 0.000097 	Training Accuracy: 95.2728 	Validation Loss: 0.000791 	Validation Accuracy: 94.5887
# Epoch: 22 	Training Loss: 0.000095 	Training Accuracy: 95.9751 	Validation Loss: 0.000788 	Validation Accuracy: 95.2381
# Epoch: 23 	Training Loss: 0.000094 	Training Accuracy: 96.3263 	Validation Loss: 0.000776 	Validation Accuracy: 95.4545
# Validation loss decreased (0.000782 --> 0.000776).  Saving model ...
# Epoch: 24 	Training Loss: 0.000095 	Training Accuracy: 95.9481 	Validation Loss: 0.000771 	Validation Accuracy: 95.6710
# Validation loss decreased (0.000776 --> 0.000771).  Saving model ...
# Epoch: 25 	Training Loss: 0.000098 	Training Accuracy: 95.1108 	Validation Loss: 0.000791 	Validation Accuracy: 94.3723
# Epoch: 26 	Training Loss: 0.000095 	Training Accuracy: 95.8131 	Validation Loss: 0.000795 	Validation Accuracy: 94.3723
# Epoch: 27 	Training Loss: 0.000095 	Training Accuracy: 96.0292 	Validation Loss: 0.000796 	Validation Accuracy: 94.8052
# Epoch: 28 	Training Loss: 0.000095 	Training Accuracy: 96.1642 	Validation Loss: 0.000814 	Validation Accuracy: 93.0736
# Epoch: 29 	Training Loss: 0.000095 	Training Accuracy: 95.7861 	Validation Loss: 0.000773 	Validation Accuracy: 95.2381
# Epoch: 30 	Training Loss: 0.000094 	Training Accuracy: 96.2723 	Validation Loss: 0.000781 	Validation Accuracy: 95.2381
# Epoch: 31 	Training Loss: 0.000094 	Training Accuracy: 96.2183 	Validation Loss: 0.000805 	Validation Accuracy: 93.7229
# Epoch: 32 	Training Loss: 0.000093 	Training Accuracy: 96.6505 	Validation Loss: 0.000823 	Validation Accuracy: 92.8571
# Epoch: 33 	Training Loss: 0.000095 	Training Accuracy: 96.1912 	Validation Loss: 0.000791 	Validation Accuracy: 94.5887
# Epoch: 34 	Training Loss: 0.000096 	Training Accuracy: 95.5970 	Validation Loss: 0.000775 	Validation Accuracy: 95.6710
# Epoch: 35 	Training Loss: 0.000094 	Training Accuracy: 96.3263 	Validation Loss: 0.000791 	Validation Accuracy: 94.5887
# Epoch: 36 	Training Loss: 0.000094 	Training Accuracy: 96.2993 	Validation Loss: 0.000792 	Validation Accuracy: 94.5887
# Epoch: 37 	Training Loss: 0.000094 	Training Accuracy: 96.6234 	Validation Loss: 0.000805 	Validation Accuracy: 93.9394
# Epoch: 38 	Training Loss: 0.000096 	Training Accuracy: 95.5429 	Validation Loss: 0.000794 	Validation Accuracy: 94.8052
# Epoch: 39 	Training Loss: 0.000093 	Training Accuracy: 96.6505 	Validation Loss: 0.000796 	Validation Accuracy: 94.3723
# Epoch: 40 	Training Loss: 0.000094 	Training Accuracy: 96.2453 	Validation Loss: 0.000773 	Validation Accuracy: 95.2381
# Epoch: 41 	Training Loss: 0.000093 	Training Accuracy: 96.7315 	Validation Loss: 0.000769 	Validation Accuracy: 95.6710
# Validation loss decreased (0.000771 --> 0.000769).  Saving model ...
# Epoch: 42 	Training Loss: 0.000098 	Training Accuracy: 94.7596 	Validation Loss: 0.000798 	Validation Accuracy: 94.3723
# Epoch: 43 	Training Loss: 0.000095 	Training Accuracy: 96.2453 	Validation Loss: 0.000804 	Validation Accuracy: 93.7229
# Epoch: 44 	Training Loss: 0.000093 	Training Accuracy: 96.7315 	Validation Loss: 0.000794 	Validation Accuracy: 94.1558
# Epoch: 45 	Training Loss: 0.000094 	Training Accuracy: 96.2723 	Validation Loss: 0.000765 	Validation Accuracy: 95.6710
# Validation loss decreased (0.000769 --> 0.000765).  Saving model ...
# Epoch: 46 	Training Loss: 0.000094 	Training Accuracy: 96.4073 	Validation Loss: 0.000796 	Validation Accuracy: 93.9394
# Epoch: 47 	Training Loss: 0.000096 	Training Accuracy: 95.6240 	Validation Loss: 0.000768 	Validation Accuracy: 95.8874
# Epoch: 48 	Training Loss: 0.000094 	Training Accuracy: 96.4344 	Validation Loss: 0.000804 	Validation Accuracy: 93.5065
# Epoch: 49 	Training Loss: 0.000093 	Training Accuracy: 96.7045 	Validation Loss: 0.000782 	Validation Accuracy: 95.0216
# Epoch: 50 	Training Loss: 0.000094 	Training Accuracy: 96.2993 	Validation Loss: 0.000787 	Validation Accuracy: 94.3723

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## **Testing the Model**

# %%
# Defining the test function

def test(loaders, model, criterion, use_cuda):

    # monitoring test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.
    preds = []
    targets = []

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # moving to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # updating average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # converting the output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        preds.append(pred)
        targets.append(target)
        # compare predictions
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
    
    return preds, targets

# calling test function
preds, targets = test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)

# %% [markdown]
# ## **Visulizing the results**

# %%
#converting the tensor object to a list for metric functions

preds2, targets2 = [],[]

for i in preds:
  for j in range(len(i)):
    preds2.append(i.cpu().numpy()[j])
for i in targets:
  for j in range(len(i)):
    targets2.append(i.cpu().numpy()[j])

# %%
#plotting the confusion matrix for testing data

cm = confusion_matrix(preds2, targets2)
print('Confusion Matrix:\n', cm)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()
# Out:
# Confusion Matrix:
#  [[217  12]
#  [ 14 219]]

# %%
#Computing the 5 evaluation metrics and printing

acc = accuracy_score(targets2, preds2)

fpr, tpr, _ = roc_curve(targets2, preds2)

area = roc_auc_score(targets2, preds2)
print("AUC score: ", area)

print("Accuracy: ", acc)

f1 = f1_score(targets2, preds2)
print("F1 score: ", f1)

pre = precision_score(targets2, preds2)
print("Precision score: ", pre)

recall = recall_score(targets2, preds2)
print("Recall score: ", recall)

plt.plot(fpr, tpr)
# Out:
# AUC score:  0.9437229437229439
# Accuracy:  0.9437229437229437
# F1 score:  0.9439655172413793
# Precision score:  0.9399141630901288
# Recall score:  0.948051948051948

# %%
#Plotting the training loss

plt.plot(range(1,51),train_loss)
plt.title("Training loss")
plt.xlabel('Epochs')
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
#Plotting the validation loss

plt.plot(range(1,1+n_epochs),valid_loss)
plt.title("Validation loss")
plt.xlabel('Epochs')
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
